# %% [markdown]
# ## Concatenating text strings

# %% [markdown]
# #### Method 1

# %%
f_name = "Qasim"

# %%
l_name = "Hassan"

# %%
full_name = f_name+l_name
print(full_name)
# Out:
# QasimHassan

# %%
full_name = f_name+" "+l_name
print(full_name)
# Out:
# Qasim Hassan

# %%
greeting = "Hello"
separators = ", "
addressee = "World"
punc = "!"
whole_greeting = greeting + separators + addressee + punc
print(whole_greeting)
# Out:
# Hello, World!

# %% [markdown]
# #### Method 2

# %%
f"{f_name} {l_name}"
# Out:
# 'Qasim Hassan'

# %%
print(f"{f_name} {l_name}")
# Out:
# Qasim Hassan

# %%
pora_name = f"{f_name} {l_name}"
print(pora_name)
# Out:
# Qasim Hassan

# %%
print(f"pora name ha mera => {f_name} {l_name}")
# Out:
# pora name ha mera => Qasim Hassan
