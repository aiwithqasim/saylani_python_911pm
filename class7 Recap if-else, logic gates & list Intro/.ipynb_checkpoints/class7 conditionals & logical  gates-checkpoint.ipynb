# %%
importance = 0
veg_type = input("Enter Vegetable type (Fresh/Not Fresh): ")
veg_price = input("Enter Vegetabel Price (High/Low): ")

if veg_type == "Fresh":
    importance = 10
elif veg_price == "Low":
    importance = 7
else:
    print('Goto Next Shop')

print(importance)
# Out:
# Enter Vegetable type (Fresh/Not Fresh): Not Fresh
# Enter Vegetabel Price (High/Low): High
# Goto Next Shop
# 0

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 1- AND
# 2- OR
# 3- NOT
#
# ![image.png](attachment:image.png)

# %%
num1 = int(input("Enter Number: "))
# Out:
# Enter Number: 12

# %%
12 > 10
# Out:
# True

# %%
num1 > 10
# Out:
# True

# %%
12 == 15
# Out:
# False

# %%
num1 == 5
# Out:
# False

# %%
(num1 > 10) and (num1 == 15)
# Out:
# False

# %% [raw]
# AND Operator
#
# True , True => True
# False, False =>  False
# True, False => False
# False, True => False
#
# OR Operator
#
# True , True => True
# False, False =>  False
# True, False => True
# False, True => Ture

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
15 != 10
# Out:
# True

# %%
15 != 15
# Out:
# False

# %%
country = input("Enter your country: ")
height = float(input("What is your height: ")) # height can be in floats

if (not country == "Paksitan") and (height > 5):
    print('Mehmood is Agreed')
else:
    print('Conditions not matched')
# Out:
# Enter your country: Turkey
# What is your height: 6
# Mehmood is Agreed

# %%
# single line comment
'''
 Multi line comments
 yes, this is multiline comments
 Ok, I know
'''
# Out:
# '\n Multi line comments\n yes, this is multiline comments\n Ok, I know\n'

# %%
num1 = int(input("enter num1: "))
num2 = int(input("enter num2: "))

if num1 == num2:
    print('checking next condition')
    num3 = int(input("enter num3: "))
    num4 = int(input("enter num4: "))
    # secodn conditions starts belwo
    if num3 > num4:
        print('yes all conditions meet')
    else:
        print('second condition not meet')
else:
    print('num1 & num2 are not equal')
# Out:
# enter num1: 3
# enter num2: 3
# checking next condition
# enter num3: 10
# enter num4: 5
# yes all conditions meet

# %%
# This is a comment.
# This is another comment.
# Python ignores these comments.
# The code that Python executes is next, on lin

# %%
'''
This is a comment.
This is another comment.
Python ignores these comments.
The code that Python executes is on line 7.
'''
print("Hello, world!")
# Out:
# Hello, world!

# %%
num2 = 2
num2
# Out:
# 2

# %% [markdown]
# ### Lists

# %%
country1 = "Pakistan"
country2 = "Turkey"
country3 = "Azerbaijan"
country4 = "China"

# %%
print(f"Welcome to {country3}")
# Out:
# Welcome to Azerbaijan

# %%
asian_countries = ["Pakistan",
                   "Turkey",
                   'Azerbaijan',
                   "China"]

# %%
asian_countries
# Out:
# ['Pakistan', 'Turkey', 'Azerbaijan', 'China']

# %%
type(asian_countries)
# Out:
# list

# %%
id(asian_countries)
# Out:
# 2384352284032

# %%
print(f"Welcome to {asian_countries[2]}")
# Out:
# Welcome to Azerbaijan

# %%
employee_list = [ 'Qasim', 'Hasssan', 6, '0310-2907555', False]

# %%
employee_list[3]
# Out:
# '0300-2337565'

# %%
# left to right
#    0           1          2            3
['Pakistan', 'Turkey', 'Azerbaijan', 'China']
# right to left
#    -4         -3           -2        -1
# Out:
# ['Pakistan', 'Turkey', 'Azerbaijan', 'China']

# %%
asian_countries[2]
# Out:
# 'Azerbaijan'

# %%
asian_countries[0:2] # start-include , last -> not incude
# Out:
# ['Pakistan', 'Turkey']

# %%
asian_countries[1:3] # 1 2 3
# Out:
# ['Turkey', 'Azerbaijan']

# %%
asian_countries[1:5]
# Out:
# ['Turkey', 'Azerbaijan', 'China']

# %%
asian_countries[1:]
# Out:
# ['Turkey', 'Azerbaijan', 'China']

# %%
asian_countries[:]
# Out:
# ['Pakistan', 'Turkey', 'Azerbaijan', 'China']

# %%
asian_countries
# Out:
# ['Pakistan', 'Turkey', 'Azerbaijan', 'China']

# %%
asian_countries[2][4:]
# Out:
# 'baijan'

# %%
asian_countries[2][4:]
